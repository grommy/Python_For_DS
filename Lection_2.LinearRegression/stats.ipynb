# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
mu, sigma = 30, 10  # mean and standard deviation
# s = np.random.normal(mu, sigma, 2000)
s = np.random.random(2000)
print(", ".join(str(i) for i in s))
# Out:
# 0.09055254614015018, 0.9320515825292225, 0.8610819106638212, 0.7640952396630174, 0.8825368361626043, 0.2764292847152928, 0.7835494368324785, 0.3808671579925371, 0.06792194628774717, 0.34313873174957754, 0.7993515857487822, 0.009433406343324124, 0.2834794591127927, 0.7121180125641922, 0.03341415248483404, 0.18560290052717143, 0.9773650969446704, 0.820718621769633, 0.49908121954735274, 0.9313182309043556, 0.0646599955028242, 0.05286761929446293, 0.7266271385496547, 0.11722725663524047, 0.21040483466956794, 0.6519302314518137, 0.8166852329777905, 0.9880649037798771, 0.30720875201106324, 0.16532380762955534, 0.7599535961197451, 0.866540870490825, 0.6921953324590533, 0.01370592237174928, 0.9535215409484175, 0.28827881952145784, 0.5239673418909222, 0.17020647700800717, 0.29951400162390385, 0.22010028754603994, 0.003708848064059911, 0.9143956843439037, 0.9001551291621867, 0.5794404737349705, 0.6935994698814831, 0.9465251158975589, 0.3303972463161896, 0.46973012556458726, 0.19760538551355689
# ...

# %%
plt.hist(s)
plt.show()

# %%
1 - 1 / (1 + np.exp(3))
# Out:
# 0.9525741268224333

# %%
l = [(0,0.1),(1, -0.1),(2,0.2),(3,0.15),(4,0.2),(5, -0.1),(6,0.5),(7,0.7),(8,0.3),(9,1.0)]
x = [t[0] for t in l]
y = [t[1] for t in l]

plt.plot(x,y)

# %%
a = -0.1

# %%
1/np.log2(2) + 1/np.log2(4) + 1/np.log2(5)
# Out:
# 1.9306765580733931
